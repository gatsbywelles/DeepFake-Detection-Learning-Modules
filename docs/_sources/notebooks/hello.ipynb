# %% [markdown]
# # Hello Notebook
# This page demonstrates a simple executable notebook. Try running it in Colab via the launch button.

# %%
import sys, platform
print('Hello from Jupyter Book!')
print(f'Python: {sys.version.split()[0]} on {platform.system()}')
